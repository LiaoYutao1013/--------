# %%
"""实验任务：使用用电量数据集，分析用电量的分布情况，进行时序预测，并进行数据可视化。
   数据集：用电量数据集包含了某地区不同时间段的用电量记录。每条记录包括时间戳和对应的用电量值。"""

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
"""Load the ETT dataset for sequence forecasting.

ETTh1.csv contains hourly electricity transformer measurements.
Use OT as the prediction target and the other columns as features.
"""
from pathlib import Path

ett_url = "https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv"

# Prefer a local ETTh1.csv if it exists, then fall back to the public URL.
search_roots = [Path.cwd(), *list(Path.cwd().parents)[:3]]
patterns = ["ETTh1.csv", "datasets/ETTh1.csv", "*/datasets/ETTh1.csv", "*/*/datasets/ETTh1.csv"]
local_candidates = []
for root in search_roots:
    for pattern in patterns:
        local_candidates.extend(root.glob(pattern))

data_source = next((p for p in dict.fromkeys(local_candidates) if p.is_file()), ett_url)
df = pd.read_csv(data_source, parse_dates=["date"])
df = df.sort_values("date").set_index("date")

target_col = "OT"
feature_cols = [col for col in df.columns if col != target_col]

# Keep X/y names so the later modeling code can stay the same.
X = df[feature_cols]
y = df[target_col]

print(f"data source: {data_source}")
print(f"shape: {df.shape}")
print(f"time range: {df.index.min()} -> {df.index.max()}")
print(f"target: {target_col}")
print(f"features: {feature_cols}")
display(df.head())
# Out:
# data source: E:\Office\BaiduSyncdisk\机器视觉学习笔记\99_Attachments (图片、PDF、附件)\datasets\ETTh1.csv
# shape: (17420, 7)
# time range: 2016-07-01 00:00:00 -> 2018-06-26 19:00:00
# target: OT
# features: ['HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL']
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
"""用DLinearity模型分析用电量的分布情况。"""
from statsmodels.tsa.deterministic import DeterministicProcess
dp = DeterministicProcess(
    index=df.index,
    constant=False,               # dummy feature for bias (y-intercept)
    order=1,                    # trend (order 1 means linear)
    seasonal=False,              # No seasonality
    drop=True,                  # drop terms if necessary to avoid collinearity
)

X_trend = dp.in_sample() #Trend预测项
X_seasonal = dp.out_of_sample(steps=42)  # Seasonal残差项

"""以trend和seasonal特征之和作为预测值，拟合ARIMA模型并进行预测。"""
X_combined = X_trend + X_seasonal
#归一化
y_normalized = (y - y.mean()) / y.std()
X_combined_normalized = (X_combined - X_combined.mean()) / X_combined.std()
model_trend = ARIMA(endog=y_normalized, exog=X_combined_normalized, order=(0, 0, 0))
result_trend = model_trend.fit()
print(result_trend.summary())



# Plot the original data and the fitted trend line
plt.figure(figsize=(12, 6))
plt.plot(df.index, y, label='Original Data', color='blue')
plt.plot(df.index, result_trend.fittedvalues, label='Fitted Trend Line', color='red')
plt.title('Electricity Consumption and Fitted Trend Line')
plt.xlabel('Date')
plt.ylabel('Electricity Consumption (OT)')
plt.legend()
plt.show()
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                     OT   No. Observations:                17420
# Model:                          ARIMA   Log Likelihood             -134191.941
# Date:                Sun, 24 May 2026   AIC                         268389.882
# Time:                        22:13:28   BIC                         268413.178
# Sample:                    07-01-2016   HQIC                        268397.555
#                          - 06-26-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.5779   1393.638      0.016      0.987   -2708.902    2754.058
# trend         -0.0011      0.180     -0.006      0.995      -0.353       0.351
# sigma2      7.813e+05   1.18e+04     65.936      0.000    7.58e+05    8.05e+05
# ===================================================================================
# Ljung-Box (L1) (Q):               17095.09   Jarque-Bera (JB):                55.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.27   Skew:                             0.12
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## 多变量 DLinear 预测：任务定义与数据窗口
#
# 下面开始的是一个**多变量驱动的简化版 DLinear**。前面的 ARIMA 示例保留不动，作为对照；这里改成直接使用 ETTh1 中所有变量的历史值共同预测未来 `OT`。
#
# ### 输入与输出
#
# 设某个历史窗口为 `x ∈ R^{L×C}`：
#
# - `L = seq_len`：输入历史长度，这里是过去 336 个小时。
# - `C = n_features`：输入变量个数，即 `feature_cols + [target_col]`。
# - `P = pred_len`：预测步长，这里是未来 42 个小时。
#
# 模型学习的映射是：
#
# $$f: R^{L \times C} \rightarrow R^P$$
#
# 也就是用一个多变量历史窗口，一次性输出未来 42 个 `OT` 预测值。
#
# ### 关键参数
#
# - `seq_len`：历史窗口长度。越大，模型看到的上下文越长，但参数量也更大。
# - `pred_len`：预测长度。这里固定为 42。
# - `test_len`：最后 42 个点作为测试集，不参与训练。
# - `batch_size`：每次训练更新使用的样本数。
# - `epochs`：完整遍历训练集的轮数。
# - `lr`：Adam 优化器的学习率。
#
# 第一个代码块完成标准化、滑动窗口构造和 `DataLoader` 封装。

# %%
"""对ETTh1使用多变量DLinear模型进行预测，并评估模型性能。"""
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# 参数
seq_len = 336      # 用过去 336 小时预测
pred_len = 42      # 预测未来 42 小时
test_len = 42
batch_size = 64
epochs = 30
lr = 1e-3

# 多变量输入：ETTh1 的所有变量历史都作为驱动变量
input_cols = feature_cols + [target_col]
train_end = len(df) - test_len

x_scaler = StandardScaler()
y_scaler = StandardScaler()

x_scaler.fit(df[input_cols].iloc[:train_end])
y_scaler.fit(df[[target_col]].iloc[:train_end])

X_all = x_scaler.transform(df[input_cols]).astype(np.float32)
y_all = y_scaler.transform(df[[target_col]]).astype(np.float32).ravel()

def make_windows(X, y, seq_len, pred_len):
    Xs, ys = [], []
    for i in range(len(X) - seq_len - pred_len + 1):
        Xs.append(X[i:i + seq_len])
        ys.append(y[i + seq_len:i + seq_len + pred_len])
    return np.array(Xs, dtype=np.float32), np.array(ys, dtype=np.float32)

X_train, y_train = make_windows(
    X_all[:train_end],
    y_all[:train_end],
    seq_len,
    pred_len
)

train_loader = DataLoader(
    TensorDataset(torch.tensor(X_train), torch.tensor(y_train)),
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# ### DLinear 的数学原理与模型类
#
# DLinear 的核心是假设时间序列可以拆成趋势项和季节/残差项：
#
# $$x = trend + seasonal$$
#
# 趋势项由滑动平均近似：
#
# $$trend_t = MA_k(x_t)$$
#
# 季节项是原序列减去趋势项：
#
# $$seasonal_t = x_t - trend_t$$
#
# 然后分别用线性层预测未来：
#
# $$\hat{y} = W_t \cdot vec(trend) + W_s \cdot vec(seasonal)$$
#
# 这里的 `vec(.)` 表示把 `[seq_len, n_features]` 展平成一维向量。本实现把所有变量一起展平，因此线性层可以同时学习时间依赖和变量间关系。
#
# ### 类与方法
#
# `MovingAvg.__init__(kernel_size)`：保存滑动窗口大小，并创建 `AvgPool1d`。
#
# `MovingAvg.forward(x)`：输入形状为 `[B, L, C]`，先在序列两端复制 padding，再计算滑动平均，输出同形状的趋势项。
#
# `DLinearMultiVar.__init__(seq_len, pred_len, n_features, kernel_size)`：创建趋势分支和季节分支两个线性层，输入维度是 `seq_len * n_features`，输出维度是 `pred_len`。
#
# `DLinearMultiVar.forward(x)`：先分解出 `trend` 和 `seasonal`，再展平、线性映射、相加，得到最终预测。

# %%
class MovingAvg(nn.Module):
    def __init__(self, kernel_size):
        super().__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=1)

    def forward(self, x):
        # x: [B, L, C]
        pad = (self.kernel_size - 1) // 2
        front = x[:, 0:1, :].repeat(1, pad, 1)
        end = x[:, -1:, :].repeat(1, pad, 1)
        x = torch.cat([front, x, end], dim=1)

        x = x.permute(0, 2, 1)   # [B, C, L]
        x = self.avg(x)
        x = x.permute(0, 2, 1)   # [B, L, C]
        return x


class DLinearMultiVar(nn.Module):
    def __init__(self, seq_len, pred_len, n_features, kernel_size=25):
        super().__init__()
        self.moving_avg = MovingAvg(kernel_size)

        # 多变量驱动：把所有变量的 trend/seasonal 历史都用于预测 OT
        in_dim = seq_len * n_features
        self.trend_linear = nn.Linear(in_dim, pred_len)
        self.seasonal_linear = nn.Linear(in_dim, pred_len)

    def forward(self, x):
        # x: [B, L, C]
        trend = self.moving_avg(x)
        seasonal = x - trend

        trend = trend.reshape(trend.size(0), -1)
        seasonal = seasonal.reshape(seasonal.size(0), -1)

        return self.trend_linear(trend) + self.seasonal_linear(seasonal)

# %% [markdown]
# ### 训练逻辑
#
# 训练时使用标准的 PyTorch 回归流程：
#
# 1. `model.train()` 进入训练模式。
# 2. 从 `train_loader` 取出一个 batch：`xb` 是历史窗口，`yb` 是未来 42 个真实值。
# 3. `pred = model(xb)` 得到预测。
# 4. `loss = MSE(pred, yb)` 计算误差。
# 5. `loss.backward()` 反向传播。
# 6. `optimizer.step()` 更新参数。
#
# 损失函数是均方误差：
#
# $$L = \frac{1}{BP} \sum_{b=1}^{B} \sum_{p=1}^{P} (\hat{y}_{b,p} - y_{b,p})^2$$
#
# 其中 `B` 是 batch size，`P = pred_len`。`device` 会优先使用 GPU，没有 GPU 时回退到 CPU。

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model = DLinearMultiVar(
    seq_len=seq_len,
    pred_len=pred_len,
    n_features=len(input_cols)
).to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

for epoch in range(epochs):
    model.train()
    losses = []

    for xb, yb in train_loader:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())

    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1:02d}, Loss: {np.mean(losses):.6f}")
# Out:
# Epoch 05, Loss: 0.119109
# Epoch 10, Loss: 0.121390
# Epoch 15, Loss: 0.122098
# Epoch 20, Loss: 0.122854
# Epoch 25, Loss: 0.117708
# Epoch 30, Loss: 0.127891

# %% [markdown]
# ### 预测、反归一化与评估
#
# 测试时只取训练集末尾的 `seq_len` 个点作为输入窗口：
#
# $$X_{test} \in R^{1 \times seq\_len \times n\_features}$$
#
# 模型一次性输出未来 42 个标准化空间中的预测值。由于训练时对 `OT` 做了标准化，所以预测后必须使用 `y_scaler.inverse_transform` 反归一化，才能和原始尺度的真实值比较。
#
# 评估指标：
#
# - `MSE`：均方误差，对较大的预测偏差更敏感。
# - `MAE`：平均绝对误差，更直观地表示平均偏差大小。
#
# 这里评估的是最后 42 个真实点，属于 hold-out 测试，不是训练集内拟合。

# %%
# 用训练集最后 seq_len 个点预测测试集未来 42 个点
X_test = X_all[train_end - seq_len:train_end]
X_test = torch.tensor(X_test[None, :, :], dtype=torch.float32).to(device)

model.eval()
with torch.no_grad():
    y_pred_norm = model(X_test).cpu().numpy().reshape(-1, 1)

y_pred = y_scaler.inverse_transform(y_pred_norm).ravel()
y_true = df[target_col].iloc[train_end:train_end + pred_len].values

mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# MSE: 4.7638
# MAE: 1.8791

# %% [markdown]
# ### 结果可视化
#
# 最后一个代码块把真实 `OT` 和预测 `OT` 画在同一张图上：
#
# - 蓝线是真实值。
# - 红线是模型预测值。
#
# 如果红线能跟随蓝线的趋势和波动，说明模型捕捉到了短期动态；如果预测明显滞后、过于平滑或振幅偏小，通常可以优先调整 `seq_len`、`kernel_size`、`epochs` 或学习率。

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index[train_end:train_end + pred_len], y_true, label="True OT", color="blue")
plt.plot(df.index[train_end:train_end + pred_len], y_pred, label="Predicted OT", color="red")
plt.title("Multivariate DLinear Forecast on ETTh1")
plt.xlabel("Date")
plt.ylabel("OT")
plt.legend()
plt.show()

# %% [markdown]
# ## PatchTST Forecasting on ETTh1
#
# PatchTST first cuts a long history window into short temporal patches, then uses a Transformer encoder to model the patch sequence. The block below trains a compact channel-independent PatchTST on all 7 ETTh1 variables and evaluates the `OT` channel.
#
# The split stays consistent with the DLinear example: the last `pred_len` hours are held out as the test horizon.

# %%
import copy
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# PatchTST hyperparameters. Increase epochs/d_model after this runs correctly.
patch_seq_len = 336
patch_pred_len = 42
patch_len = 16
patch_stride = 8
patch_batch_size = 64
patch_epochs = 20
patch_lr = 1e-3
patch_d_model = 64
patch_n_heads = 4
patch_num_layers = 2
patch_d_ff = 128
patch_dropout = 0.1

patch_input_cols = feature_cols + [target_col]
patch_target_idx = patch_input_cols.index(target_col)
patch_test_len = patch_pred_len
patch_train_end = len(df) - patch_test_len

patch_scaler = StandardScaler()
patch_scaler.fit(df[patch_input_cols].iloc[:patch_train_end])
patch_values = patch_scaler.transform(df[patch_input_cols]).astype(np.float32)

def make_multivar_windows(values, seq_len, pred_len, end_idx):
    Xs, ys = [], []
    stop = end_idx - seq_len - pred_len + 1
    for i in range(stop):
        Xs.append(values[i:i + seq_len])
        ys.append(values[i + seq_len:i + seq_len + pred_len])
    return np.stack(Xs).astype(np.float32), np.stack(ys).astype(np.float32)

X_patch, y_patch = make_multivar_windows(
    patch_values,
    seq_len=patch_seq_len,
    pred_len=patch_pred_len,
    end_idx=patch_train_end,
)

# Chronological train/validation split inside the training period.
n_val = max(1, int(len(X_patch) * 0.1))
X_patch_train, X_patch_val = X_patch[:-n_val], X_patch[-n_val:]
y_patch_train, y_patch_val = y_patch[:-n_val], y_patch[-n_val:]

patch_train_loader = DataLoader(
    TensorDataset(torch.from_numpy(X_patch_train), torch.from_numpy(y_patch_train)),
    batch_size=patch_batch_size,
    shuffle=True,
)
patch_val_loader = DataLoader(
    TensorDataset(torch.from_numpy(X_patch_val), torch.from_numpy(y_patch_val)),
    batch_size=patch_batch_size,
    shuffle=False,
)

print(f"train windows: {X_patch_train.shape}, val windows: {X_patch_val.shape}")
print(f"target channel: {target_col}, target index: {patch_target_idx}")
# Out:
# train windows: (15301, 336, 7), val windows: (1700, 336, 7)
# target channel: OT, target index: 6

# %%
class ChannelIndependentPatchTST(nn.Module):
    def __init__(
        self,
        seq_len,
        pred_len,
        n_channels,
        patch_len=16,
        stride=8,
        d_model=64,
        n_heads=4,
        num_layers=2,
        d_ff=128,
        dropout=0.1,
    ):
        super().__init__()
        self.seq_len = seq_len
        self.pred_len = pred_len
        self.n_channels = n_channels
        self.patch_len = patch_len
        self.stride = stride
        self.n_patches = (seq_len - patch_len) // stride + 1

        self.patch_embedding = nn.Linear(patch_len, d_model)
        self.position_embedding = nn.Parameter(torch.zeros(1, self.n_patches, d_model))
        self.dropout = nn.Dropout(dropout)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=d_ff,
            dropout=dropout,
            activation="gelu",
            batch_first=True,
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.head = nn.Linear(self.n_patches * d_model, pred_len)

        nn.init.normal_(self.position_embedding, std=0.02)

    def forward(self, x):
        # x: [batch, seq_len, channels]
        batch_size, _, n_channels = x.shape
        x = x.permute(0, 2, 1)  # [batch, channels, seq_len]

        patches = x.unfold(dimension=-1, size=self.patch_len, step=self.stride)
        # patches: [batch, channels, n_patches, patch_len]
        patches = patches.reshape(batch_size * n_channels, self.n_patches, self.patch_len)

        z = self.patch_embedding(patches)
        z = z + self.position_embedding
        z = self.dropout(z)
        z = self.encoder(z)
        z = z.reshape(batch_size * n_channels, -1)

        out = self.head(z)  # [batch * channels, pred_len]
        out = out.reshape(batch_size, n_channels, self.pred_len)
        return out.permute(0, 2, 1)  # [batch, pred_len, channels]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

patch_model = ChannelIndependentPatchTST(
    seq_len=patch_seq_len,
    pred_len=patch_pred_len,
    n_channels=len(patch_input_cols),
    patch_len=patch_len,
    stride=patch_stride,
    d_model=patch_d_model,
    n_heads=patch_n_heads,
    num_layers=patch_num_layers,
    d_ff=patch_d_ff,
    dropout=patch_dropout,
).to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(patch_model.parameters(), lr=patch_lr, weight_decay=1e-4)

best_state = None
best_val_loss = float("inf")
patience = 5
bad_epochs = 0

for epoch in range(1, patch_epochs + 1):
    patch_model.train()
    train_losses = []

    for xb, yb in patch_train_loader:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad()
        pred = patch_model(xb)

        # Train all channels. If you only care about OT, replace this with:
        # loss = criterion(pred[:, :, patch_target_idx], yb[:, :, patch_target_idx])
        loss = criterion(pred, yb)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(patch_model.parameters(), max_norm=1.0)
        optimizer.step()
        train_losses.append(loss.item())

    patch_model.eval()
    val_losses = []
    with torch.no_grad():
        for xb, yb in patch_val_loader:
            xb = xb.to(device)
            yb = yb.to(device)
            pred = patch_model(xb)
            val_loss = criterion(pred, yb)
            val_losses.append(val_loss.item())

    train_loss = float(np.mean(train_losses))
    val_loss = float(np.mean(val_losses))

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state = copy.deepcopy(patch_model.state_dict())
        bad_epochs = 0
    else:
        bad_epochs += 1

    if epoch == 1 or epoch % 5 == 0:
        print(f"Epoch {epoch:02d} | train loss: {train_loss:.6f} | val loss: {val_loss:.6f}")

    if bad_epochs >= patience:
        print(f"Early stopping at epoch {epoch}; best val loss: {best_val_loss:.6f}")
        break

if best_state is not None:
    patch_model.load_state_dict(best_state)
# Out:
# Epoch 01 | train loss: 0.357882 | val loss: 0.314334

# %%
X_patch_test = patch_values[patch_train_end - patch_seq_len:patch_train_end]
X_patch_test = torch.tensor(X_patch_test[None, :, :], dtype=torch.float32).to(device)

patch_model.eval()
with torch.no_grad():
    patch_pred_norm = patch_model(X_patch_test).cpu().numpy()[0]  # [pred_len, channels]

patch_pred_raw = patch_scaler.inverse_transform(patch_pred_norm)
patch_true_raw = df[patch_input_cols].iloc[patch_train_end:patch_train_end + patch_pred_len].values

patch_y_pred = patch_pred_raw[:, patch_target_idx]
patch_y_true = patch_true_raw[:, patch_target_idx]

patch_mse = mean_squared_error(patch_y_true, patch_y_pred)
patch_mae = mean_absolute_error(patch_y_true, patch_y_pred)

print(f"PatchTST MSE: {patch_mse:.4f}")
print(f"PatchTST MAE: {patch_mae:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(df.index[patch_train_end:patch_train_end + patch_pred_len], patch_y_true, label="True OT", color="blue")
plt.plot(df.index[patch_train_end:patch_train_end + patch_pred_len], patch_y_pred, label="PatchTST Predicted OT", color="red")
plt.title("PatchTST Forecast on ETTh1")
plt.xlabel("Date")
plt.ylabel("OT")
plt.legend()
plt.show()
